# %%
gtgrtgrtgr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 gtgrtgrtgr
#
# NameError: name 'gtgrtgrtgr' is not defined

# %%
kjkkuik
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 kjkkuik
#
# NameError: name 'kjkkuik' is not defined

# %%
a=10

# %%
b=15

# %%
a+b
# Out:
# 25
